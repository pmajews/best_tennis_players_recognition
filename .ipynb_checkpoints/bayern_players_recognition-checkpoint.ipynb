# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for dirname, _, filenames in os.walk(r'C:\Users\przem\Desktop\bayern_players_recognition\model\dataset\alphonso-davies\alphonso-davies (9).jpg'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
img = cv2.imread(r'C:\Users\przem\Desktop\bayern_players_recognition\model\dataset\alphonso-davies\alphonso-davies (9).jpg')

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier(r'C:\Users\przem\Desktop\bayern_players_recognition\model\opencv\haarcascades\haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(r'C:\Users\przem\Desktop\bayern_players_recognition\model\opencv\haarcascades\haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[268,  52, 145, 145]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (268, 52, 145, 145)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
path_to_data = r"C:\Users\przem\Desktop\bayern_players_recognition\model\dataset"
path_to_cropped_data = r"C:\Users\przem\Desktop\bayern_players_recognition\model\dataset\cropped"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\alphonso-davies',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\benjamin-pavard',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\bouna-sarr',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\christian-fruechtl',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\corentin-tolisso',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\cropped',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\dayot-upamecano',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\eric-maxim-choupo-moting',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\jamal-musiala',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\joshua-kimmich',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\josip-stanisic',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\kingsley-coman',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\leon-goretzka',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\leroy-sane',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\lucas-hernandez',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\malik-tillman',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\manuel-neuer',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\marc-roca',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\marcel-sabitzer',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\niklas-sule',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\omar-richards',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\paul-wanner',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\robert-lewandowski',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\serge-gnabry',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\sven-ulreich',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\tanguy-nianzou',
#  'C:\\Users\\przem\\Desktop\\bayern_players_recognition\\model\\dataset\\thomas-mueller']

# %%
import shutil
if os.path.exists(path_to_cropped_data):
    shutil.rmtree(path_to_cropped_data)
os.mkdir(path_to_cropped_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('\\')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cropped_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".jpg"
            cropped_file_path = cropped_folder + "\\" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# alphonso-davies
# benjamin-pavard
# bouna-sarr
# christian-fruechtl
# corentin-tolisso
# cropped
# dayot-upamecano
# eric-maxim-choupo-moting
# jamal-musiala
# joshua-kimmich
# josip-stanisic
# kingsley-coman
# leon-goretzka
# leroy-sane
# lucas-hernandez
# malik-tillman
# manuel-neuer
# marc-roca
# marcel-sabitzer
# niklas-sule
# omar-richards
# paul-wanner
# robert-lewandowski
# serge-gnabry
# sven-ulreich
# tanguy-nianzou
# thomas-mueller

# %%
print(celebrity_name)
# Out:
# thomas-mueller
